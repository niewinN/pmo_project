# %% [markdown]
# # Notatnik: eksploracja danych i modelu

# %%
import os, sys
sys.path.append(os.path.join(os.getcwd(), 'src'))
from utils import DATA_ROOT, CLIPS_DIR, TRAIN_TSV, DEV_TSV
print('DATA_ROOT:', DATA_ROOT)
print('TRAIN_TSV exists:', os.path.exists(TRAIN_TSV))
